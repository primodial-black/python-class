# %%
class student:
    stud_count=0
    stud_subs=3
    stud_details={}
    def __init__(self,studName,phone,email,address,mark1,mark2,mark3):
        self.stud_name = studName
        self.stud_phone = phone
        self.stud_email = email
        self.stud_address = address
        self.stud_mark1 = mark1
        self.stud_mark2 = mark2
        self.stud_mark3 = mark3
        self.inc_student_count()
        self.stud_id=100+self.stud_count
        self.setStudDetails(self.stud_id,self)

    @classmethod
    def inc_student_count(cls):
        cls.stud_count+=1

    @classmethod
    def setStudDetails(cls,stud_id,self):
            cls.stud_details[stud_id]=self

    def calculate_total(self,mark1,mark2,mark3):
         return mark1 + mark2 + mark3
    
    @classmethod
    def displayStudDetails(cls):
        print('Student ID', 'Student Name ', 'phone number', 'email', 'address', 'mark1', 'mark2', 'mark3',sep='  |  ')
        for i in cls.stud_details:
            print(cls.stud_details[i].stud_id, 
                  cls.stud_details[i].stud_name, 
                  cls.stud_details[i].stud_phone,
                  cls.stud_details[i].stud_email,
                  cls.stud_details[i].stud_address,
                  cls.stud_details[i].stud_mark1,
                  cls.stud_details[i].stud_mark2,
                  cls.stud_details[i].stud_mark3, sep='  |  ')

    @classmethod
    def Display_specific_student(cls,id):
        obj=cls.stud_details[id]
        print("Student ID : ",obj.stud_id)
        print("Student Name : ",obj.stud_name)
        print("Phone Number : ",obj.stud_phone)
        print("Email Address : ",obj.stud_email)
        print("Address : ",obj.stud_address)
        print("Mark 1 : ",obj.stud_mark1)
        print("Mark 2 : ",obj.stud_mark2)
        print("Mark 3 : ",obj.stud_mark3)
        print("Total Marks : ",obj.calculate_total(obj.stud_mark1,obj.stud_mark2,obj.stud_mark3))
    
    def modify_marks(self,mar):
        print(self.stud_mark1,self.stud_mark2,self.stud_mark3)
        if mar == 1:
            self.stud_mark1 = int(input("enter new mark"))
        elif mar == 2:
            self.stud_mark2 = int(input("enter new mark"))
        elif mar == 3:
            self.stud_mark3 = int(input("enter new mark"))
        print(self.stud_mark1,self.stud_mark2,self.stud_mark3)
    

    def change_school_phone(self):
        print(self.stud_phone)
        self.stud_phone = int(input("enter new phone"))
        print(self.stud_phone)


    @classmethod   
    def add_new_student(cls):
        name = input("Enter Student's Name")
        phone = int(input("Enter Phone number"))
        email = input("Enter Email address")
        address = input("Enter Address")
        mark1 = int(input("Enter Mark 1"))
        mark2 = int(input("Enter Mark 2"))
        mark3 = int(input("Enter Mark 3"))
        cls.setStudDetails(cls.stud_count+1,student(name,phone,email,address,mark1,mark2,mark3))
        cls.stud_count += 1

   
   #to call all above methods
    @classmethod                                            
    def main(cls,self):
        n=int(input("choose 1.modify marks \n 2.change  phone \n 3.calculate total \n 4.display student details \n 5. Display specific student \n 6.Add new student \n 7.Exit"))
        match n:
                case 1:
                    mar=int(input("enter the choice mark to modify"))
                    self.modify_marks(mar)
                case 2:
                    self.change_school_phone()
                case 3:
                    self.calculate_total()
                case 4:
                    cls.displayStudDetails()
                case 5:
                    id=int(input("Enter student id"))
                    if id in cls.stud_details:
                        cls.Display_specific_student(id)
                    else:
                        print("id not there")
                case 6:
                    cls.add_new_student()
                case _:
                    return
        return cls.main(self)
    
    
    
                
ahamad=student("Ahamad",7794994036,"ahamad@gmail.com","hyd",80,76,92)
riyaz=student("riyaz",1122334455,"riyaz@gmail.com","hyd",65,67,84)
ghouse=student("ghouse",7791234566,"ghouse@gmail.com","hyd",88,82,95)
nabeel=student("nabeel",9988665544,"nabeel@gmail.com","hyd",83,79,91)                                                           
nabeel1=student("nabeel",9988665544,"nabeel@gmail.com","hyd",83,79,91)   


student.main(ahamad)
# Out:
# Student ID  |  Student Name   |  phone number  |  email  |  address  |  mark1  |  mark2  |  mark3
# 101  |  Ahamad  |  7794994036  |  ahamad@gmail.com  |  hyd  |  80  |  76  |  92
# 102  |  riyaz  |  1122334455  |  riyaz@gmail.com  |  hyd  |  65  |  67  |  84
# 103  |  ghouse  |  7791234566  |  ghouse@gmail.com  |  hyd  |  88  |  82  |  95
# 104  |  nabeel  |  9988665544  |  nabeel@gmail.com  |  hyd  |  83  |  79  |  91
# 105  |  nabeel  |  9988665544  |  nabeel@gmail.com  |  hyd  |  83  |  79  |  91
# 106  |  vasu  |  112233445566  |  vasu@gmail.com  |  hyd  |  86  |  78  |  90
# 106  |  vasu  |  112233445566  |  vasu@gmail.com  |  hyd  |  86  |  78  |  90
# Student ID :  106
# Student Name :  vasu
# Phone Number :  112233445566
# Email Address :  vasu@gmail.com
# Address :  hyd
# Mark 1 :  86
# Mark 2 :  78
# Mark 3 :  90
# Total Marks :  254

# %%
student.stud_details[101]

# %%
student.main(ahamad)
# Out:
# Student ID  |  Student Name   |  phone number  |  email  |  address  |  mark1  |  mark2  |  mark3
# 101  |  Ahamad  |  7794994036  |  ahamad@gmail.com  |  hyd  |  80  |  76  |  92
# 102  |  riyaz  |  1122334455  |  riyaz@gmail.com  |  hyd  |  65  |  45  |  84
# 103  |  ghouse  |  7791234566  |  ghouse@gmail.com  |  hyd  |  88  |  82  |  95
# 104  |  nabeel  |  9988665544  |  nabeel@gmail.com  |  hyd  |  83  |  79  |  91
# 105  |  nabeel  |  9988665544  |  nabeel@gmail.com  |  hyd  |  83  |  79  |  91

# %%
student.main(ahamad)

# %%
student.stud_details
student.stud_details[101].__dict__

# %%
class Student:
    college_name = "Pyspyders"
    college_code = "A1-123"
    stream = "Ece"
    student_count = 0
    stu_details = {}
    college_info = {}
    def __init__(self, stu_name, phone, email, address, mark1, mark2, mark3):
        self.stu_name = stu_name
        self.phone = phone
        self.email = email
        self.address = address
        self.mark1 = mark1
        self.mark2 = mark2
        self.mark3 = mark3
        Student.stu_count_inc()
        self.student_id = 100 + Student.student_count
        self.setStudDetails(self.student_id, self)

    @classmethod
    def stu_count_inc(cls):
        cls.student_count += 1

    @classmethod
    def setStudDetails(cls, id, obj):
        cls.stu_details[id] = obj

    def student_info(self):
        n = int(input(
            "Choose the option:\n0. Calculate Total\n1. Display Student Details\n2. Display Specific Student\n3. Modify Marks\n4. Change Phone No\n5. Exit"))
        print("-" * 150)
        match n:
            case 0:
                self.calculate_total()
            case 1:
                self.display_stud_details()
            case 2:
                self.display_specific_student()
            case 3:
                self.modify_marks()
            case 4:
                self.change_phn_no()
            case _:
                return
        return self.student_info()

    def calculate_total(self):
        total = self.mark1 + self.mark2 + self.mark3
        print(total)
        percentage = (total / 100) * 300
        return percentage

    def display_stud_details(self):
        total_marks = self.calculate_total()
        percentage = total_marks / 3
        print(f"Student ID: {self.student_id}, Name: {self.stu_name}, Total Marks: {total_marks}, Percentage: {percentage}%")

    def display_specific_student(self):
        print(f"Student ID: {self.student_id}")
        print(f"Total: {self.calculate_total()}")

    def modify_marks(self):
        new_mark1 = int(input("Enter the new mark1: "))
        self.mark1 = new_mark1
        new_mark2 = int(input("Enter the new mark2: "))
        self.mark2 = new_mark2
        new_mark3 = int(input("Enter the new mark3: "))
        self.mark3 = new_mark3
        print(f"modified marks: {new_mark1} , {new_mark2} , {new_mark3}")
        

    def change_phn_no(self):
        new_phone = int(input("Enter the new phone: "))
        self.phone = new_phone
        print(f"modified phone.no: {new_phone}")


Student1 = Student("anya", 8723654789, "anya@gmail.com", "Nellore", 90, 97, 78)
print(Student1.__dict__)
Student2 = Student("nemo", 8721234789, "nemo@gmail.com", "Nellore", 93, 47, 73)
print(Student2.__dict__)
Student3 = Student("bhujji", 8789654789, "bhujji@gmail.com", "Nellore", 94, 67, 98)
print(Student3.__dict__)
Student4 = Student("Dora", 8721234789, "dora@gmail.com", "Nellore", 80, 77, 58)
print(Student4.__dict__)




Student1.display_stud_details()
Student2.display_stud_details()
Student3.display_stud_details()
Student4.display_stud_details()

Student1.student_info()
Student2.student_info()
Student3.student_info()
Student4.student_info()
# Out:
# {'stu_name': 'anya', 'phone': 8723654789, 'email': 'anya@gmail.com', 'address': 'Nellore', 'mark1': 90, 'mark2': 97, 'mark3': 78, 'student_id': 101}
# {'stu_name': 'nemo', 'phone': 8721234789, 'email': 'nemo@gmail.com', 'address': 'Nellore', 'mark1': 93, 'mark2': 47, 'mark3': 73, 'student_id': 102}
# {'stu_name': 'bhujji', 'phone': 8789654789, 'email': 'bhujji@gmail.com', 'address': 'Nellore', 'mark1': 94, 'mark2': 67, 'mark3': 98, 'student_id': 103}
# {'stu_name': 'Dora', 'phone': 8721234789, 'email': 'dora@gmail.com', 'address': 'Nellore', 'mark1': 80, 'mark2': 77, 'mark3': 58, 'student_id': 104}
# 265
# Student ID: 101, Name: anya, Total Marks: 795.0, Percentage: 265.0%
# 213
# Student ID: 102, Name: nemo, Total Marks: 639.0, Percentage: 213.0%
# 259
# Student ID: 103, Name: bhujji, Total Marks: 777.0, Percentage: 259.0%
# 215
# Student ID: 104, Name: Dora, Total Marks: 645.0, Percentage: 215.0%
# ...
